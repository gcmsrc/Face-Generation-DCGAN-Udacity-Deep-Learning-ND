# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
#data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# /Users/gsarchioni/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    
    # Define input paramter
    real_inputs = tf.placeholder(tf.float32,
                                 (None, image_width, image_height, image_channels), 
                                 name='real_inputs')
    
    z_input = tf.placeholder(tf.float32,
                             (None, z_dim),
                             name='z_inputs')
    
    lr = tf.placeholder(tf.float32,
                        name='learning_rate')
    
    return real_inputs, z_input, lr


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    # Note that input layer is 28 x 28 x image_channel
    
    # Define leaky relu_function (alpha = 0.2)
    alpha = 0.2
    leaky_relu = lambda x: tf.maximum(alpha * x, x)
    
    # Define conv_layer function
    def conv_layer(inputs, filters, kernel_size, strides, batch_norm=True):
        hidden = tf.layers.conv2d(inputs,
                                  filters,
                                  kernel_size,
                                  strides,
                                  padding='same',
                                  kernel_initializer=tf.contrib.layers.xavier_initializer())
        if batch_norm:
            hidden = tf.layers.batch_normalization(hidden, training=True)
        
        hidden = leaky_relu(hidden)
        
        # Add dropout
        hidden = tf.layers.dropout(hidden, 0.5, training=True)
        
        return hidden
    
    with tf.variable_scope('discriminator', reuse=reuse):
        # First layer
        h0 = conv_layer(images, 64, 5, 2, batch_norm=False) # 14 x 14
        h1 = conv_layer(h0, 128, 5, 2) # 7 x 7
        h2 = conv_layer(h1, 256, 3, 1) # 7 x 7
        h3 = conv_layer(h2, 512, 3, 2) # 4 x 4
        
        # Logits and outputs
        flat = tf.reshape(h2, (-1, 4 * 4 * 512))
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)
        
        return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    
    # Define leaky relu_function (alpha = 0.2)
    alpha = 0.2
    leaky_relu = lambda x: tf.maximum(alpha * x, x)
    
    # Define initialiser
    k_init = tf.contrib.layers.xavier_initializer()
    
    # def deconv
    def deconv(inputs, filters, kernel_size, strides, training, init = k_init):
        
        dec_layer = tf.layers.conv2d_transpose(inputs,
                                               filters,
                                               kernel_size, 
                                               strides, 
                                               padding='same', 
                                               kernel_initializer=k_init)

        dec_layer = tf.layers.batch_normalization(dec_layer, training=training)
        dec_layer = leaky_relu(dec_layer)
        
        # Apply dropout
        dec_layer = tf.layers.dropout(dec_layer, 0.5, training=training)
        
        return dec_layer
        
    
    with tf.variable_scope('generator', reuse=not is_train):
        
        
        h1 = tf.layers.dense(z, 7 * 7 * 512)
        h1 = tf.reshape(h1, (-1, 7, 7, 512))
        h1 = tf.layers.batch_normalization(h1, training=is_train)
        h1 = leaky_relu(h1) # 7 x 7
        
        h2 = deconv(h1, 256, 3, 2, training=is_train) # 14 x 14
        h3 = deconv(h2, 128, 5, 1, training=is_train) # 14 x 14
        h4 = deconv(h3, 64, 5, 2, training=is_train) # 28 x 28
        
        logits = tf.layers.conv2d_transpose(h4, out_channel_dim, 5, 1, 'same') # 28 x 28
        out = tf.tanh(logits)
        
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    
    # Ouputs of generator and discriminator
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)
    
    # Smoothing factor
    smooth = 0.1
    
    # Calculate losses
    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real,
                                                labels=tf.ones_like(d_model_real) * (1-smooth)))
    
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                labels=tf.zeros_like(d_model_fake)))
    
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                labels=tf.ones_like(d_model_fake)))
    
    d_loss = d_loss_real + d_loss_fake
    
    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    
    # Get variables
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]
    
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train = tf.train.AdamOptimizer(learning_rate, beta1).minimize(d_loss, var_list = d_vars)
        g_train = tf.train.AdamOptimizer(learning_rate, beta1).minimize(g_loss, var_list=g_vars)
    
        return d_train, g_train


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    
    # Build input placeholders
    _, image_width, image_height, image_channels = data_shape
    
    input_real, input_z, lr = model_inputs(image_width, image_height, image_channels, z_dim)
    
    # Define losses
    d_loss, g_loss = model_loss(input_real, input_z, image_channels)
    
    # Definie optimisers
    d_opt, g_opt = model_opt(d_loss, g_loss, lr, beta1)
    
    steps = 0
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for e in range(epoch_count):
            for batch_images in get_batches(batch_size):
                
                steps += 1
                
                # MNIST dataset is between -0.5 and 0.5. Need to fix it by multiplying by 2
                batch_images = batch_images * 2.0
           
                # Sample random data from the generator
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                
                # Run optimisers
                _ = sess.run(d_opt, feed_dict={input_real : batch_images, 
                                               input_z : batch_z, 
                                               lr : learning_rate})
                _ = sess.run(g_opt, feed_dict={input_real : batch_images,
                                               input_z : batch_z, 
                                               lr : learning_rate})
                
                if steps % 10 == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = d_loss.eval({input_real: batch_images, input_z: batch_z})
                    train_loss_g = g_loss.eval({input_z: batch_z})
                    
                    print("Epoch {}/{}...".format(e+1, epoch_count),
                          "Batch {}...".format(steps),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))

                if steps % 100 == 0:
                    show_generator_output(sess, 25, input_z, image_channels, data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64
z_dim = 100
learning_rate = 1e-3
beta1 = 0.3


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Batch 10... Discriminator Loss: 0.8363... Generator Loss: 1.2512
# Epoch 1/2... Batch 20... Discriminator Loss: 1.0332... Generator Loss: 2.0544
# Epoch 1/2... Batch 30... Discriminator Loss: 2.1044... Generator Loss: 2.7211
# Epoch 1/2... Batch 40... Discriminator Loss: 1.3403... Generator Loss: 1.3265
# Epoch 1/2... Batch 50... Discriminator Loss: 1.3489... Generator Loss: 0.5255
# Epoch 1/2... Batch 60... Discriminator Loss: 0.5945... Generator Loss: 1.9663
# Epoch 1/2... Batch 70... Discriminator Loss: 0.4812... Generator Loss: 2.3071
# Epoch 1/2... Batch 80... Discriminator Loss: 1.4414... Generator Loss: 1.9174
# Epoch 1/2... Batch 90... Discriminator Loss: 1.7463... Generator Loss: 2.1073
# Epoch 1/2... Batch 100... Discriminator Loss: 1.7194... Generator Loss: 1.6163
# Epoch 1/2... Batch 110... Discriminator Loss: 1.3929... Generator Loss: 0.6960
# Epoch 1/2... Batch 120... Discriminator Loss: 1.5512... Generator Loss: 0.4283
# Epoch 1/2... Batch 130... Discriminator Loss: 1.3791... Generator Loss: 0.6048
# Epoch 1/2... Batch 140... Discriminator Loss: 1.2673... Generator Loss: 0.7608
# Epoch 1/2... Batch 150... Discriminator Loss: 1.4464... Generator Loss: 0.4934
# Epoch 1/2... Batch 160... Discriminator Loss: 1.4888... Generator Loss: 1.4440
# Epoch 1/2... Batch 170... Discriminator Loss: 1.5539... Generator Loss: 1.5956
# Epoch 1/2... Batch 180... Discriminator Loss: 1.5160... Generator Loss: 1.1806
# Epoch 1/2... Batch 190... Discriminator Loss: 1.3535... Generator Loss: 0.6315
# Epoch 1/2... Batch 200... Discriminator Loss: 1.4210... Generator Loss: 0.5259
# Epoch 1/2... Batch 210... Discriminator Loss: 1.3635... Generator Loss: 0.7326
# Epoch 1/2... Batch 220... Discriminator Loss: 1.4438... Generator Loss: 1.2421
# Epoch 1/2... Batch 230... Discriminator Loss: 1.4688... Generator Loss: 1.3525
# Epoch 1/2... Batch 240... Discriminator Loss: 1.3257... Generator Loss: 1.1409
# Epoch 1/2... Batch 250... Discriminator Loss: 1.3663... Generator Loss: 0.7785
# Epoch 1/2... Batch 260... Discriminator Loss: 1.4548... Generator Loss: 0.5111
# Epoch 1/2... Batch 270... Discriminator Loss: 1.3514... Generator Loss: 0.9734
# Epoch 1/2... Batch 280... Discriminator Loss: 1.6652... Generator Loss: 1.5905
# Epoch 1/2... Batch 290... Discriminator Loss: 1.3421... Generator Loss: 1.0670
# Epoch 1/2... Batch 300... Discriminator Loss: 1.5785... Generator Loss: 1.3405
# Epoch 1/2... Batch 310... Discriminator Loss: 1.4456... Generator Loss: 1.2807
# Epoch 1/2... Batch 320... Discriminator Loss: 1.3609... Generator Loss: 0.8329
# Epoch 1/2... Batch 330... Discriminator Loss: 1.4291... Generator Loss: 1.1920
# Epoch 1/2... Batch 340... Discriminator Loss: 1.4051... Generator Loss: 1.2121
# Epoch 1/2... Batch 350... Discriminator Loss: 1.4364... Generator Loss: 1.0425
# Epoch 1/2... Batch 360... Discriminator Loss: 1.4180... Generator Loss: 1.0517
# Epoch 1/2... Batch 370... Discriminator Loss: 1.6267... Generator Loss: 1.6242
# Epoch 1/2... Batch 380... Discriminator Loss: 1.5173... Generator Loss: 0.4790
# Epoch 1/2... Batch 390... Discriminator Loss: 1.3515... Generator Loss: 0.6925
# Epoch 1/2... Batch 400... Discriminator Loss: 1.5560... Generator Loss: 0.4477
# Epoch 1/2... Batch 410... Discriminator Loss: 1.4588... Generator Loss: 0.5280
# Epoch 1/2... Batch 420... Discriminator Loss: 1.4102... Generator Loss: 0.9764
# Epoch 1/2... Batch 430... Discriminator Loss: 1.3894... Generator Loss: 1.0695
# Epoch 1/2... Batch 440... Discriminator Loss: 1.3968... Generator Loss: 1.0313
# Epoch 1/2... Batch 450... Discriminator Loss: 1.3698... Generator Loss: 0.9629
# Epoch 1/2... Batch 460... Discriminator Loss: 1.4084... Generator Loss: 1.1339
# Epoch 2/2... Batch 470... Discriminator Loss: 1.3666... Generator Loss: 0.9552
# Epoch 2/2... Batch 480... Discriminator Loss: 1.3680... Generator Loss: 0.6398
# Epoch 2/2... Batch 490... Discriminator Loss: 1.5359... Generator Loss: 0.4455
# Epoch 2/2... Batch 500... Discriminator Loss: 1.4852... Generator Loss: 0.4952
# Epoch 2/2... Batch 510... Discriminator Loss: 1.4214... Generator Loss: 0.5579
# Epoch 2/2... Batch 520... Discriminator Loss: 1.3624... Generator Loss: 0.8477
# Epoch 2/2... Batch 530... Discriminator Loss: 1.4983... Generator Loss: 1.3925
# Epoch 2/2... Batch 540... Discriminator Loss: 1.4565... Generator Loss: 1.2682
# Epoch 2/2... Batch 550... Discriminator Loss: 1.4286... Generator Loss: 0.8663
# Epoch 2/2... Batch 560... Discriminator Loss: 1.4326... Generator Loss: 0.5326
# Epoch 2/2... Batch 570... Discriminator Loss: 1.3927... Generator Loss: 0.5689
# Epoch 2/2... Batch 580... Discriminator Loss: 1.3620... Generator Loss: 0.6388
# Epoch 2/2... Batch 590... Discriminator Loss: 1.4340... Generator Loss: 0.5437
# Epoch 2/2... Batch 600... Discriminator Loss: 1.4743... Generator Loss: 0.4898
# Epoch 2/2... Batch 610... Discriminator Loss: 1.3519... Generator Loss: 0.8749
# Epoch 2/2... Batch 620... Discriminator Loss: 1.5435... Generator Loss: 1.4353
# Epoch 2/2... Batch 630... Discriminator Loss: 1.3723... Generator Loss: 1.0418
# Epoch 2/2... Batch 640... Discriminator Loss: 1.4451... Generator Loss: 1.3826
# Epoch 2/2... Batch 650... Discriminator Loss: 1.3388... Generator Loss: 0.9616
# Epoch 2/2... Batch 660... Discriminator Loss: 1.5619... Generator Loss: 1.4445
# Epoch 2/2... Batch 670... Discriminator Loss: 1.2959... Generator Loss: 0.9445
# Epoch 2/2... Batch 680... Discriminator Loss: 1.4431... Generator Loss: 1.2002
# Epoch 2/2... Batch 690... Discriminator Loss: 1.3488... Generator Loss: 1.0150
# Epoch 2/2... Batch 700... Discriminator Loss: 1.3903... Generator Loss: 1.0841
# Epoch 2/2... Batch 710... Discriminator Loss: 1.5643... Generator Loss: 1.4507
# Epoch 2/2... Batch 720... Discriminator Loss: 1.3440... Generator Loss: 0.9688
# Epoch 2/2... Batch 730... Discriminator Loss: 1.3614... Generator Loss: 1.1088
# Epoch 2/2... Batch 740... Discriminator Loss: 1.3886... Generator Loss: 1.0200
# Epoch 2/2... Batch 750... Discriminator Loss: 1.3247... Generator Loss: 0.8734
# Epoch 2/2... Batch 760... Discriminator Loss: 1.3812... Generator Loss: 1.0685
# Epoch 2/2... Batch 770... Discriminator Loss: 1.3953... Generator Loss: 1.1906
# Epoch 2/2... Batch 780... Discriminator Loss: 1.4214... Generator Loss: 1.2883
# Epoch 2/2... Batch 790... Discriminator Loss: 1.4525... Generator Loss: 1.3277
# Epoch 2/2... Batch 800... Discriminator Loss: 1.3502... Generator Loss: 0.8989
# Epoch 2/2... Batch 810... Discriminator Loss: 1.4230... Generator Loss: 0.5818
# Epoch 2/2... Batch 820... Discriminator Loss: 1.3599... Generator Loss: 0.6280
# Epoch 2/2... Batch 830... Discriminator Loss: 1.3260... Generator Loss: 0.6308
# Epoch 2/2... Batch 840... Discriminator Loss: 1.4224... Generator Loss: 0.5333
# Epoch 2/2... Batch 850... Discriminator Loss: 1.4409... Generator Loss: 0.5160
# Epoch 2/2... Batch 860... Discriminator Loss: 1.3604... Generator Loss: 0.6666
# Epoch 2/2... Batch 870... Discriminator Loss: 1.4141... Generator Loss: 0.5476
# Epoch 2/2... Batch 880... Discriminator Loss: 1.3301... Generator Loss: 0.6844
# Epoch 2/2... Batch 890... Discriminator Loss: 1.3927... Generator Loss: 0.6216
# Epoch 2/2... Batch 900... Discriminator Loss: 2.0272... Generator Loss: 0.3734
# Epoch 2/2... Batch 910... Discriminator Loss: 1.3116... Generator Loss: 0.8940
# Epoch 2/2... Batch 920... Discriminator Loss: 1.3651... Generator Loss: 1.1135
# Epoch 2/2... Batch 930... Discriminator Loss: 1.3812... Generator Loss: 0.5585

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 64
z_dim = 128
learning_rate = 0.0005
beta1 = 0.6


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Batch 10... Discriminator Loss: 2.3329... Generator Loss: 0.2213
# Epoch 1/1... Batch 20... Discriminator Loss: 1.4158... Generator Loss: 0.6295
# Epoch 1/1... Batch 30... Discriminator Loss: 1.5995... Generator Loss: 0.4583
# Epoch 1/1... Batch 40... Discriminator Loss: 1.1698... Generator Loss: 0.7815
# Epoch 1/1... Batch 50... Discriminator Loss: 1.2031... Generator Loss: 0.7699
# Epoch 1/1... Batch 60... Discriminator Loss: 0.8274... Generator Loss: 1.4839
# Epoch 1/1... Batch 70... Discriminator Loss: 0.7557... Generator Loss: 1.5028
# Epoch 1/1... Batch 80... Discriminator Loss: 0.8683... Generator Loss: 1.5963
# Epoch 1/1... Batch 90... Discriminator Loss: 1.4795... Generator Loss: 2.1411
# Epoch 1/1... Batch 100... Discriminator Loss: 0.8132... Generator Loss: 1.5216
# Epoch 1/1... Batch 110... Discriminator Loss: 0.5337... Generator Loss: 2.0598
# Epoch 1/1... Batch 120... Discriminator Loss: 0.4345... Generator Loss: 2.7276
# Epoch 1/1... Batch 130... Discriminator Loss: 0.3755... Generator Loss: 3.3317
# Epoch 1/1... Batch 140... Discriminator Loss: 0.4214... Generator Loss: 3.0402
# Epoch 1/1... Batch 150... Discriminator Loss: 0.6358... Generator Loss: 2.1354
# Epoch 1/1... Batch 160... Discriminator Loss: 0.5525... Generator Loss: 2.1720
# Epoch 1/1... Batch 170... Discriminator Loss: 0.5884... Generator Loss: 1.7971
# Epoch 1/1... Batch 180... Discriminator Loss: 0.5639... Generator Loss: 2.0975
# Epoch 1/1... Batch 190... Discriminator Loss: 0.4195... Generator Loss: 3.4085
# Epoch 1/1... Batch 200... Discriminator Loss: 0.3856... Generator Loss: 3.3987
# Epoch 1/1... Batch 210... Discriminator Loss: 0.3595... Generator Loss: 3.8742
# Epoch 1/1... Batch 220... Discriminator Loss: 0.3577... Generator Loss: 4.0485
# Epoch 1/1... Batch 230... Discriminator Loss: 0.3956... Generator Loss: 3.1677
# Epoch 1/1... Batch 240... Discriminator Loss: 0.6159... Generator Loss: 2.0241
# Epoch 1/1... Batch 250... Discriminator Loss: 1.0307... Generator Loss: 2.8355
# Epoch 1/1... Batch 260... Discriminator Loss: 0.6016... Generator Loss: 2.3030
# Epoch 1/1... Batch 270... Discriminator Loss: 1.0669... Generator Loss: 1.1811
# Epoch 1/1... Batch 280... Discriminator Loss: 1.3499... Generator Loss: 0.5210
# Epoch 1/1... Batch 290... Discriminator Loss: 1.7135... Generator Loss: 0.7231
# Epoch 1/1... Batch 300... Discriminator Loss: 0.9142... Generator Loss: 1.1899
# Epoch 1/1... Batch 310... Discriminator Loss: 1.5607... Generator Loss: 0.7063
# Epoch 1/1... Batch 320... Discriminator Loss: 1.2065... Generator Loss: 1.4865
# Epoch 1/1... Batch 330... Discriminator Loss: 1.1652... Generator Loss: 1.1201
# Epoch 1/1... Batch 340... Discriminator Loss: 0.9690... Generator Loss: 0.9399
# Epoch 1/1... Batch 350... Discriminator Loss: 1.0845... Generator Loss: 1.4196
# Epoch 1/1... Batch 360... Discriminator Loss: 1.1815... Generator Loss: 1.0448
# Epoch 1/1... Batch 370... Discriminator Loss: 1.1735... Generator Loss: 0.7181
# Epoch 1/1... Batch 380... Discriminator Loss: 1.3478... Generator Loss: 0.7381
# Epoch 1/1... Batch 390... Discriminator Loss: 1.1737... Generator Loss: 1.3207
# Epoch 1/1... Batch 400... Discriminator Loss: 1.1539... Generator Loss: 1.0437
# Epoch 1/1... Batch 410... Discriminator Loss: 0.9833... Generator Loss: 1.4477
# Epoch 1/1... Batch 420... Discriminator Loss: 1.2135... Generator Loss: 0.9050
# Epoch 1/1... Batch 430... Discriminator Loss: 1.3863... Generator Loss: 0.8728
# Epoch 1/1... Batch 440... Discriminator Loss: 1.1851... Generator Loss: 1.2189
# Epoch 1/1... Batch 450... Discriminator Loss: 1.3190... Generator Loss: 0.6408
# Epoch 1/1... Batch 460... Discriminator Loss: 1.2928... Generator Loss: 0.8228
# Epoch 1/1... Batch 470... Discriminator Loss: 1.3482... Generator Loss: 1.0905
# Epoch 1/1... Batch 480... Discriminator Loss: 1.4034... Generator Loss: 0.7577
# Epoch 1/1... Batch 490... Discriminator Loss: 2.1850... Generator Loss: 1.5646
# Epoch 1/1... Batch 500... Discriminator Loss: 1.2640... Generator Loss: 0.8621
# Epoch 1/1... Batch 510... Discriminator Loss: 1.4296... Generator Loss: 0.7932
# Epoch 1/1... Batch 520... Discriminator Loss: 1.0260... Generator Loss: 1.4003
# Epoch 1/1... Batch 530... Discriminator Loss: 1.1646... Generator Loss: 0.7528
# Epoch 1/1... Batch 540... Discriminator Loss: 1.4040... Generator Loss: 0.7462
# Epoch 1/1... Batch 550... Discriminator Loss: 1.3904... Generator Loss: 0.9544
# Epoch 1/1... Batch 560... Discriminator Loss: 1.4787... Generator Loss: 0.8064
# Epoch 1/1... Batch 570... Discriminator Loss: 1.2025... Generator Loss: 1.4200
# Epoch 1/1... Batch 580... Discriminator Loss: 1.1739... Generator Loss: 0.9509
# Epoch 1/1... Batch 590... Discriminator Loss: 1.2570... Generator Loss: 0.8681
# Epoch 1/1... Batch 600... Discriminator Loss: 1.3831... Generator Loss: 1.0463
# Epoch 1/1... Batch 610... Discriminator Loss: 1.1826... Generator Loss: 0.8048
# Epoch 1/1... Batch 620... Discriminator Loss: 1.4229... Generator Loss: 0.6398
# Epoch 1/1... Batch 630... Discriminator Loss: 1.3244... Generator Loss: 0.7370
# Epoch 1/1... Batch 640... Discriminator Loss: 1.1403... Generator Loss: 1.2827
# Epoch 1/1... Batch 650... Discriminator Loss: 1.3754... Generator Loss: 0.8151
# Epoch 1/1... Batch 660... Discriminator Loss: 1.2429... Generator Loss: 1.0028
# Epoch 1/1... Batch 670... Discriminator Loss: 1.4425... Generator Loss: 0.7658
# Epoch 1/1... Batch 680... Discriminator Loss: 1.4899... Generator Loss: 0.6532
# Epoch 1/1... Batch 690... Discriminator Loss: 1.4367... Generator Loss: 0.7471
# Epoch 1/1... Batch 700... Discriminator Loss: 1.2550... Generator Loss: 0.8346
# Epoch 1/1... Batch 710... Discriminator Loss: 1.2632... Generator Loss: 1.0484
# Epoch 1/1... Batch 720... Discriminator Loss: 1.2463... Generator Loss: 1.0478
# Epoch 1/1... Batch 730... Discriminator Loss: 1.3214... Generator Loss: 1.0818
# Epoch 1/1... Batch 740... Discriminator Loss: 1.2377... Generator Loss: 0.8891
# Epoch 1/1... Batch 750... Discriminator Loss: 1.3276... Generator Loss: 0.8736
# Epoch 1/1... Batch 760... Discriminator Loss: 1.3386... Generator Loss: 0.8848
# Epoch 1/1... Batch 770... Discriminator Loss: 1.4093... Generator Loss: 0.8900
# Epoch 1/1... Batch 780... Discriminator Loss: 1.2044... Generator Loss: 1.1373
# Epoch 1/1... Batch 790... Discriminator Loss: 1.3297... Generator Loss: 0.8324
# Epoch 1/1... Batch 800... Discriminator Loss: 1.1375... Generator Loss: 1.1023
# Epoch 1/1... Batch 810... Discriminator Loss: 1.4234... Generator Loss: 1.1112
# Epoch 1/1... Batch 820... Discriminator Loss: 1.2858... Generator Loss: 0.7690
# Epoch 1/1... Batch 830... Discriminator Loss: 1.1383... Generator Loss: 1.0253
# Epoch 1/1... Batch 840... Discriminator Loss: 1.2946... Generator Loss: 1.0735
# Epoch 1/1... Batch 850... Discriminator Loss: 1.2748... Generator Loss: 0.7903
# Epoch 1/1... Batch 860... Discriminator Loss: 1.2827... Generator Loss: 0.9786
# Epoch 1/1... Batch 870... Discriminator Loss: 1.3109... Generator Loss: 0.9988
# Epoch 1/1... Batch 880... Discriminator Loss: 1.3293... Generator Loss: 0.7725
# Epoch 1/1... Batch 890... Discriminator Loss: 1.2641... Generator Loss: 0.6276
# Epoch 1/1... Batch 900... Discriminator Loss: 1.2380... Generator Loss: 0.8818
# Epoch 1/1... Batch 910... Discriminator Loss: 1.2741... Generator Loss: 1.0801
# Epoch 1/1... Batch 920... Discriminator Loss: 1.2234... Generator Loss: 1.0305
# Epoch 1/1... Batch 930... Discriminator Loss: 1.3559... Generator Loss: 1.0270
# Epoch 1/1... Batch 940... Discriminator Loss: 1.3370... Generator Loss: 0.6742
# Epoch 1/1... Batch 950... Discriminator Loss: 1.3465... Generator Loss: 0.8850
# Epoch 1/1... Batch 960... Discriminator Loss: 1.4589... Generator Loss: 0.7079
# Epoch 1/1... Batch 970... Discriminator Loss: 1.2554... Generator Loss: 0.9418
# Epoch 1/1... Batch 980... Discriminator Loss: 1.2674... Generator Loss: 0.9021
# Epoch 1/1... Batch 990... Discriminator Loss: 1.0818... Generator Loss: 1.1519
# Epoch 1/1... Batch 1000... Discriminator Loss: 1.1644... Generator Loss: 1.0813
# Epoch 1/1... Batch 1010... Discriminator Loss: 1.4564... Generator Loss: 0.7286
# Epoch 1/1... Batch 1020... Discriminator Loss: 1.2713... Generator Loss: 0.9777
# Epoch 1/1... Batch 1030... Discriminator Loss: 1.2518... Generator Loss: 0.7861
# Epoch 1/1... Batch 1040... Discriminator Loss: 1.2904... Generator Loss: 0.7467
# Epoch 1/1... Batch 1050... Discriminator Loss: 1.3897... Generator Loss: 0.7451
# Epoch 1/1... Batch 1060... Discriminator Loss: 1.4075... Generator Loss: 0.7268
# Epoch 1/1... Batch 1070... Discriminator Loss: 1.3575... Generator Loss: 0.8243
# Epoch 1/1... Batch 1080... Discriminator Loss: 1.3744... Generator Loss: 0.7488
# Epoch 1/1... Batch 1090... Discriminator Loss: 1.1829... Generator Loss: 0.9240
# Epoch 1/1... Batch 1100... Discriminator Loss: 1.3153... Generator Loss: 0.8153
# Epoch 1/1... Batch 1110... Discriminator Loss: 1.3260... Generator Loss: 0.8387
# Epoch 1/1... Batch 1120... Discriminator Loss: 1.2595... Generator Loss: 0.9953
# Epoch 1/1... Batch 1130... Discriminator Loss: 1.2709... Generator Loss: 0.8434
# Epoch 1/1... Batch 1140... Discriminator Loss: 1.2359... Generator Loss: 1.1884
# Epoch 1/1... Batch 1150... Discriminator Loss: 1.2990... Generator Loss: 0.8701
# Epoch 1/1... Batch 1160... Discriminator Loss: 1.3297... Generator Loss: 1.0972
# Epoch 1/1... Batch 1170... Discriminator Loss: 1.3070... Generator Loss: 0.8387
# Epoch 1/1... Batch 1180... Discriminator Loss: 1.3215... Generator Loss: 0.8623
# Epoch 1/1... Batch 1190... Discriminator Loss: 1.3282... Generator Loss: 0.9467
# Epoch 1/1... Batch 1200... Discriminator Loss: 1.3299... Generator Loss: 0.6960
# Epoch 1/1... Batch 1210... Discriminator Loss: 1.4607... Generator Loss: 0.7430
# Epoch 1/1... Batch 1220... Discriminator Loss: 1.3054... Generator Loss: 0.9400
# Epoch 1/1... Batch 1230... Discriminator Loss: 1.3581... Generator Loss: 1.0894
# Epoch 1/1... Batch 1240... Discriminator Loss: 1.2473... Generator Loss: 0.8337
# Epoch 1/1... Batch 1250... Discriminator Loss: 1.3836... Generator Loss: 0.7915
# Epoch 1/1... Batch 1260... Discriminator Loss: 1.4121... Generator Loss: 0.7958
# Epoch 1/1... Batch 1270... Discriminator Loss: 1.2764... Generator Loss: 1.0492
# Epoch 1/1... Batch 1280... Discriminator Loss: 1.2016... Generator Loss: 1.0379
# Epoch 1/1... Batch 1290... Discriminator Loss: 1.2185... Generator Loss: 0.9910
# Epoch 1/1... Batch 1300... Discriminator Loss: 1.3600... Generator Loss: 0.9112
# Epoch 1/1... Batch 1310... Discriminator Loss: 1.2635... Generator Loss: 0.8957
# Epoch 1/1... Batch 1320... Discriminator Loss: 1.2860... Generator Loss: 1.0212
# Epoch 1/1... Batch 1330... Discriminator Loss: 1.4714... Generator Loss: 0.9446
# Epoch 1/1... Batch 1340... Discriminator Loss: 1.2247... Generator Loss: 0.9535
# Epoch 1/1... Batch 1350... Discriminator Loss: 1.2305... Generator Loss: 0.9217
# Epoch 1/1... Batch 1360... Discriminator Loss: 1.5337... Generator Loss: 0.6947
# Epoch 1/1... Batch 1370... Discriminator Loss: 1.0143... Generator Loss: 1.2157
# Epoch 1/1... Batch 1380... Discriminator Loss: 1.2685... Generator Loss: 0.9048
# Epoch 1/1... Batch 1390... Discriminator Loss: 1.2779... Generator Loss: 0.8061
# Epoch 1/1... Batch 1400... Discriminator Loss: 1.1922... Generator Loss: 1.2680
# Epoch 1/1... Batch 1410... Discriminator Loss: 1.0846... Generator Loss: 0.9742
# Epoch 1/1... Batch 1420... Discriminator Loss: 1.1928... Generator Loss: 0.8915
# Epoch 1/1... Batch 1430... Discriminator Loss: 1.3571... Generator Loss: 0.5720
# Epoch 1/1... Batch 1440... Discriminator Loss: 1.4074... Generator Loss: 0.9520
# Epoch 1/1... Batch 1450... Discriminator Loss: 1.3083... Generator Loss: 0.9720
# Epoch 1/1... Batch 1460... Discriminator Loss: 1.2640... Generator Loss: 0.9522
# Epoch 1/1... Batch 1470... Discriminator Loss: 1.3923... Generator Loss: 0.7931
# Epoch 1/1... Batch 1480... Discriminator Loss: 1.3441... Generator Loss: 0.9126
# Epoch 1/1... Batch 1490... Discriminator Loss: 1.7903... Generator Loss: 0.7748
# Epoch 1/1... Batch 1500... Discriminator Loss: 1.1528... Generator Loss: 0.8289
# Epoch 1/1... Batch 1510... Discriminator Loss: 1.6600... Generator Loss: 1.3771
# Epoch 1/1... Batch 1520... Discriminator Loss: 1.3199... Generator Loss: 0.8064
# Epoch 1/1... Batch 1530... Discriminator Loss: 1.4218... Generator Loss: 0.8440
# Epoch 1/1... Batch 1540... Discriminator Loss: 1.2959... Generator Loss: 0.9519
# Epoch 1/1... Batch 1550... Discriminator Loss: 1.4660... Generator Loss: 0.6793
# Epoch 1/1... Batch 1560... Discriminator Loss: 1.3714... Generator Loss: 0.7703
# Epoch 1/1... Batch 1570... Discriminator Loss: 1.4780... Generator Loss: 0.7979
# Epoch 1/1... Batch 1580... Discriminator Loss: 1.3622... Generator Loss: 0.9001
# Epoch 1/1... Batch 1590... Discriminator Loss: 1.3860... Generator Loss: 0.8110
# Epoch 1/1... Batch 1600... Discriminator Loss: 1.3227... Generator Loss: 0.7918
# Epoch 1/1... Batch 1610... Discriminator Loss: 1.3086... Generator Loss: 0.8809
# Epoch 1/1... Batch 1620... Discriminator Loss: 1.2189... Generator Loss: 0.8744
# Epoch 1/1... Batch 1630... Discriminator Loss: 1.3804... Generator Loss: 0.7279
# Epoch 1/1... Batch 1640... Discriminator Loss: 1.3149... Generator Loss: 0.8877
# Epoch 1/1... Batch 1650... Discriminator Loss: 1.3184... Generator Loss: 1.0076
# Epoch 1/1... Batch 1660... Discriminator Loss: 1.3876... Generator Loss: 0.7709
# Epoch 1/1... Batch 1670... Discriminator Loss: 1.2390... Generator Loss: 0.9356
# Epoch 1/1... Batch 1680... Discriminator Loss: 1.3102... Generator Loss: 0.8945
# Epoch 1/1... Batch 1690... Discriminator Loss: 1.4181... Generator Loss: 0.8218
# Epoch 1/1... Batch 1700... Discriminator Loss: 1.3261... Generator Loss: 0.8095
# Epoch 1/1... Batch 1710... Discriminator Loss: 1.3547... Generator Loss: 0.8190
# Epoch 1/1... Batch 1720... Discriminator Loss: 1.3659... Generator Loss: 0.7675
# Epoch 1/1... Batch 1730... Discriminator Loss: 1.3975... Generator Loss: 1.0548
# Epoch 1/1... Batch 1740... Discriminator Loss: 1.2990... Generator Loss: 0.9853
# Epoch 1/1... Batch 1750... Discriminator Loss: 1.3933... Generator Loss: 0.9404
# Epoch 1/1... Batch 1760... Discriminator Loss: 1.3613... Generator Loss: 0.8440
# Epoch 1/1... Batch 1770... Discriminator Loss: 1.2893... Generator Loss: 0.7985
# Epoch 1/1... Batch 1780... Discriminator Loss: 1.3299... Generator Loss: 0.8954
# Epoch 1/1... Batch 1790... Discriminator Loss: 1.2979... Generator Loss: 0.7554
# Epoch 1/1... Batch 1800... Discriminator Loss: 1.3222... Generator Loss: 0.8208
# Epoch 1/1... Batch 1810... Discriminator Loss: 1.3822... Generator Loss: 0.7112
# Epoch 1/1... Batch 1820... Discriminator Loss: 1.2516... Generator Loss: 0.9512
# Epoch 1/1... Batch 1830... Discriminator Loss: 1.3389... Generator Loss: 0.8816
# Epoch 1/1... Batch 1840... Discriminator Loss: 1.3106... Generator Loss: 0.9159
# Epoch 1/1... Batch 1850... Discriminator Loss: 1.2893... Generator Loss: 0.8382
# Epoch 1/1... Batch 1860... Discriminator Loss: 1.2972... Generator Loss: 1.0012
# Epoch 1/1... Batch 1870... Discriminator Loss: 1.3376... Generator Loss: 0.8696
# Epoch 1/1... Batch 1880... Discriminator Loss: 1.2723... Generator Loss: 0.8542
# Epoch 1/1... Batch 1890... Discriminator Loss: 1.2386... Generator Loss: 0.8892
# Epoch 1/1... Batch 1900... Discriminator Loss: 1.3732... Generator Loss: 0.9987
# Epoch 1/1... Batch 1910... Discriminator Loss: 1.3639... Generator Loss: 0.8031
# Epoch 1/1... Batch 1920... Discriminator Loss: 1.3538... Generator Loss: 0.9080
# Epoch 1/1... Batch 1930... Discriminator Loss: 1.3078... Generator Loss: 0.9515
# Epoch 1/1... Batch 1940... Discriminator Loss: 1.3889... Generator Loss: 0.9116
# Epoch 1/1... Batch 1950... Discriminator Loss: 1.2922... Generator Loss: 0.8606
# Epoch 1/1... Batch 1960... Discriminator Loss: 1.3853... Generator Loss: 0.7340
# Epoch 1/1... Batch 1970... Discriminator Loss: 1.3555... Generator Loss: 0.8775
# Epoch 1/1... Batch 1980... Discriminator Loss: 1.3425... Generator Loss: 0.7992
# Epoch 1/1... Batch 1990... Discriminator Loss: 1.2976... Generator Loss: 0.8493
# Epoch 1/1... Batch 2000... Discriminator Loss: 1.4086... Generator Loss: 0.9619
# Epoch 1/1... Batch 2010... Discriminator Loss: 1.3915... Generator Loss: 0.8553
# Epoch 1/1... Batch 2020... Discriminator Loss: 1.2956... Generator Loss: 0.9041
# Epoch 1/1... Batch 2030... Discriminator Loss: 1.2803... Generator Loss: 0.8942
# Epoch 1/1... Batch 2040... Discriminator Loss: 1.4231... Generator Loss: 0.6711
# Epoch 1/1... Batch 2050... Discriminator Loss: 1.3673... Generator Loss: 0.9947
# Epoch 1/1... Batch 2060... Discriminator Loss: 1.1438... Generator Loss: 0.9647
# Epoch 1/1... Batch 2070... Discriminator Loss: 1.3946... Generator Loss: 0.9688
# Epoch 1/1... Batch 2080... Discriminator Loss: 1.4033... Generator Loss: 0.8627
# Epoch 1/1... Batch 2090... Discriminator Loss: 1.3128... Generator Loss: 0.9224
# Epoch 1/1... Batch 2100... Discriminator Loss: 1.3295... Generator Loss: 0.9693
# Epoch 1/1... Batch 2110... Discriminator Loss: 1.3076... Generator Loss: 0.8624
# Epoch 1/1... Batch 2120... Discriminator Loss: 1.2551... Generator Loss: 0.9151
# Epoch 1/1... Batch 2130... Discriminator Loss: 1.3930... Generator Loss: 0.9054
# Epoch 1/1... Batch 2140... Discriminator Loss: 1.2836... Generator Loss: 0.8210
# Epoch 1/1... Batch 2150... Discriminator Loss: 1.3101... Generator Loss: 0.8897
# Epoch 1/1... Batch 2160... Discriminator Loss: 1.4058... Generator Loss: 0.6247
# Epoch 1/1... Batch 2170... Discriminator Loss: 1.3654... Generator Loss: 0.7236
# Epoch 1/1... Batch 2180... Discriminator Loss: 1.3453... Generator Loss: 0.8027
# Epoch 1/1... Batch 2190... Discriminator Loss: 1.3459... Generator Loss: 0.9043
# Epoch 1/1... Batch 2200... Discriminator Loss: 1.4339... Generator Loss: 0.7463
# Epoch 1/1... Batch 2210... Discriminator Loss: 1.3040... Generator Loss: 0.8022
# Epoch 1/1... Batch 2220... Discriminator Loss: 1.3257... Generator Loss: 0.7516
# Epoch 1/1... Batch 2230... Discriminator Loss: 1.2962... Generator Loss: 0.8630

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
